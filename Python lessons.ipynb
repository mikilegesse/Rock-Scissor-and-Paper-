# %% [markdown]
# ### Using INPUT

# %%
a = input("enter your age? ")
# Out:
# enter your age? 25

# %%
('Hello' + ' ' + input('whats your name'))
# Out:
# whats your namemiki
# 'Hello miki'

# %%
a

# %%
a= input ('Whats your name? ')
print (len(a))

# %% [markdown]
# ### Python Varialbles

# %% [markdown]
# ### Swapping Variables

# %%
a=input('a: ')
b=input('b; ')
c=a
a=b
b=c
print ("A = ", (a))
print ("B = ", (b))

# %% [markdown]
# ### Band Name Generator

# %%
a=input("what's the name of the city you grew up in?\n ")
b=input("What's your pet name ?\n ")

print("Your band name could be", (a), (b))

# %% [markdown]
# ### DATA TYPES

# %%
#indentation
print("Hello"[0])

# %% [markdown]
#  ### Type Error, Type Checking and Type Conversion

# %%
type() ### to check whether is is an integer, float, boolean or string

# %%
n=("123")
print(type(n))

# %%
n=(123)
type(n)

# %% [markdown]
# ### input two numbers and add it

# %%
a= (input('Enter two digit number? '))
b= int(a[0])
c= int(a[1])
print (b+c)

# %% [markdown]
# ### Mathematical Operators

# %%
2**3 ### 2 the power of 3 ...PEMDAS...parethesis...Exponential....Multiply...Division...Addition Subtraction

# %% [markdown]
# ### BMI Index Calculator

# %%
a= float(input('Enter weight? '))
b= float(input('Enter Height? '))
c=a/b**2
print ('Your BMI is', (c))

# %% [markdown]
# ### Number Manipulation and F Strings in Python

# %%
print(round(8/3,2))

# %%
 8//3....### this will also round the numbers

# %%
score=0
score = score + 1....### means the previous score value plus one 
score += 1

# %%
### how to use f- string###....help us to convert a lot of variables to string 


score=0
height=1.8
isWinning = True

print (f"your score is {score}, your height is {height}, your winning is {isWinning}")

# %% [markdown]
# ### TIP CALCULATOR PROJECT

# %%
print ("Welcome to the Tip Calculator")


total_bill= float(input("what is the total bill \n"))
percentage= float(input("what percentage tip would you like to give ?\n"))
split= int(input("how many people split the bill \n"))
conversion = percentage/100
total = (total_bill * conversion) + total_bill
each = round(total/split,2)

print("each person should pay \n", (each))

# %% [markdown]
# ### ODD OR EVEN NUMBER

# %%
num=int(input("enter number "))
if num%2==0:
    print((num), "is even")
else:
    print((num), "is odd")

# %% [markdown]
# ### Nested if statements and elif statements

# %%
### Modified BMI calculator

# %%
a= float(input('Enter weight? '))
b= float(input('Enter Height? '))
c=a/b**2

if c <= 18.5:
    print (c, "is underweight" )
elif c < 25:
    print (c, "is normal weight")
elif c < 30:    
    print (c, "is over weight")
elif c < 35:
    print (c, "Obese")
else:
    print("clinically obese")

# %% [markdown]
# ### Leap year project

# %%
year=int(input("enter year:? \n"))

if year%4==0: 
    if year % 100==0:
        if year % 400==0:
            print (year, "is leap year")
        else:
            print (year, "not leap year")
    else:
        print (year, "is leap year")
        
else:
    print(year, "is not leap year")

# %% [markdown]
# ###
# if/elif/else - if we use if/elif/else then means one of those will be carried out
#
# Multiple if - all of the condition should be true or will be checked and excuted
#
# ###

# %%
bill = 0
height = int(input("whats your height"))
             
if height >= 120:     
    age=int(input("how old are you ?"))
    if age < 12:
        bill = 5
        print("your bill is $5")
    elif age < 18:
        bill =  7
        print('your bill is $7')
    elif age > 18:
        bill = 12
        print ("your bill is $12")
    
    photo = input("do you want to take your photo taken? Y or N ")
                 
if photo == "Y":
    bill += 3  
    print (f"total price would be {bill}")
else: 
     print ("not today bitch!!")

# %% [markdown]
# ### Pizza order practice

# %%
print ("Welcome to the pizza delivery")

small = 15
medium = 20
large = 25
c=0
p=0


size = input("what sizza pizza do you want? S,M or L  ")
if size == "S":
    c=15
    p=15
    print ("your bill is $15")
elif size == "M":
    c=20
    p=20
    print ("your bill is $20")
elif size == "L":
    c=25
    p=20
    print ("your bill is $25")

add_pepperoni = input("do you want pepperoni? Y or N")
if add_pepperoni =="Y":
    if size == "S":
        p+=2
        print (p, "is the total price")
    else:
        p+=3
        print (p) 
        
else: 
    print(p)
extra_cheese = input("do you want extra cheese? Y or N")              
if extra_cheese =="Y":
    c=p+1
    print (c, "is the total price")
else:
    print(c)

# %% [markdown]
# ### another pizza order project

# %%
print ("Welcome to the pizza delivery")

small = 15
medium = 20
large = 25
bill = 0


size = input("what sizza pizza do you want? S,M or L  ")
if size == "S":
    bill+=15
elif size == "M":
    bill+=20
elif size == "L":
    bill+=25

add_pepperoni = input("do you want pepperoni? Y or N")
if add_pepperoni =="Y":
    if size == "S":
        bill+=2
    else:
        bill+=3         

extra_cheese = input("do you want extra cheese? Y or N")              
if extra_cheese =="Y":
    bill+=1
    print (bill, "is the total price")

# %% [markdown]
# ### Logical Operators AND, OR & nor

# %% [markdown]
# ### Love Calculator

# %%
a=input("whats your name ?\n ")
b=input("What's your lovers name ?\n ")
c=a.lower()
d=b.lower()
print (c +" "+d)
f= c.count("t") + c.count('r') + c.count ("u") + c.count("e")
g= d.count("t") + d.count('r') + d.count ("u") + d.count("e")
h=f+g
print (h)
i=c.count("l") + c.count('o') + c.count ("v") + c.count("e")
j=d.count("l") + d.count('o') + d.count ("v") + d.count("e")
k=i+j 
print(k)
l=str(h)+str(k)

print (l)
# Out:
# what's the name of the city you grew up in?
#  MIKI
# What's your pet name ?
#  Legesse
# miki legesse
# 3
# 4
# 34

# %% [markdown]
# ###  Day 3 Project: Treasure Island

# %%
print("Welcome to the treasure Island ")

print("Your Mission is to find the treasure")

direction=input("choose? L or R  \n")
if direction.lower() == "L" or "l": 
    print ("congratulation")
    survive = input("choose from swim or wait  \n")
    if survive.lower() == "swim":
        print ("congratulation")
        door = input("choose from red , yellow  or blue  \n")
        if door.lower() == "yellow":
            print ("congratulation You Win")
        else:
            print ("game over")
    else:
         print ("game over")
else:        
    print ("game over")
# Out:
# Welcome to the treasure Island
# Your Mission is to find the treasure
# choose? L or R
# R
# congratulation
# choose from swim or wait
# wait
# game over

# %% [markdown]
# ### random module

# %%
### python uses meresenne twister for randomness

# %%
import random
m = random.randint(1,2)

# %%
rand=random.random() ### create floating number between 0-1

# %%
### coin toss game

coin = random.randint(1,2)
if coin >= 1.5:
    print("head")
else:
    print("tail")
# Out:
# tail

# %% [markdown]
# ### Understanding the Offset and Appending Items to Lists

# %%
fruits = ["cherry","apple","pear"]

# %%
fruits
# Out:
# ['cherry', 'apple', 'pear']

# %%
fruits[0] ### indexing
# Out:
# 'cherry'

# %%
fruits[1]= "appu" ### replacing parts

# %%
fruits
# Out:
# ['cherry', 'appu', 'pear']

# %%
fruits.append("cherries") ### appends...data structure documentation https://docs.python.org/3/tutorial/datastructures.html

# %%
fruits
# Out:
# ['cherry', 'appu', 'pear', 'cherries']

# %%
j=input("names separated by a coma")
k=j.split(", ")### SPLIT FUNCTION TO SEPARATE LISTS IN THE COMA
l==(len(k))
m=random.randint(0, l-1)
n=k[m]
print(n)

# %% [markdown]
# ### IndexErrors and Working with Nested Lists

# %%
state_names=["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]
num=len(state_names)
print(state_names[num-1])### add -1 to ge the text and avoid error on print

# %%
fruits = ["apple", "grape","pears"]
vagetables = ["spinach","kale","celery"]

dozen = [fruits, vagetables] ### its called nested list ...a list within a list

# %%
dozen

# %%
dozen[1][1]

# %% [markdown]
# ### Treasure Map

# %%
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]

map=[row1, row2, row3]

print (f"{row1}\n{row2}\n{row3}")

choose = input("where do you want to put the treasure? \n")

if choose == "11":
    map[0][0]="X" 
    print  (f"{row1}\n{row2}\n{row3}")  
elif choose == "21":
    map[0][1]="X" 
    print  (f"{row1}\n{row2}\n{row3}")
elif choose == "31":
    map[0][2]="X" 
    print  (f"{row1}\n{row2}\n{row3}")  
elif choose == "12":
    map[1][0]="X" 
    print  (f"{row1}\n{row2}\n{row3}")   
elif choose == "22":
    map[1][1]="X" 
    print  (f"{row1}\n{row2}\n{row3}")  
elif choose == "32":
    map[1][2]="X" 
    print  (f"{row1}\n{row2}\n{row3}")  
elif choose == "13":
    map[2][0]="X" 
    print  (f"{row1}\n{row2}\n{row3}")
elif choose == "23":
    map[2][1]="X" 
    print  (f"{row1}\n{row2}\n{row3}")
elif choose == "33":
    map[2][2]="X" 
    print  (f"{row1}\n{row2}\n{row3}") 
else: 
    print("wrong entry")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']

# %%
 ### another way to do it

# %%
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]

map=[row1, row2, row3]

print (f"{row1}\n{row2}\n{row3}")

choose = input("where do you want to put the treasure? \n")

horizontal = int(choose[0])
vertical = int(choose[1])

selected_row = map[vertical-1]
selected_row[horizontal-1] = "x"

print (f"{row1}\n{row2}\n{row3}")

# %% [markdown]
# ### rock paper scissor

# %%
import random

user_action = input("Enter a choice (rock, paper, scissors): ")
game = ["rock","paper","scissor"]
computer_action = random.choice(game)
        
print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

if user_action == computer_action:
    print(f"Both players selected {user_action}. It's a tie!")
elif user_action == "rock":
    if computer_action == "scissors":
        print("Rock smashes scissors! You win!")
    else:
        print("Paper covers rock! You lose.")
elif user_action == "paper":
    if computer_action == "rock":
        print("Paper covers rock! You win!")
    else:
        print("Scissors cuts paper! You lose.")
elif user_action == "scissors":
    if computer_action == "paper":
        print("Scissors cuts paper! You win!")
    else:
        print("Rock smashes scissors! You lose.")
# Out:
# Enter a choice (rock, paper, scissors): paper
#
# You chose paper, computer chose scissor.
#
# Scissors cuts paper! You lose.

# %%
### to check your email is hacked or not go to https://haveibeenpwned.com/ and typr your email

# %% [markdown]
# ### Python LOOPS

# %%
fruits = ["apple", "grape","pears"]
for fruit in fruits:
      print(fruit)
# Out:
# apple
# grape
# pears

# %%
### using for loop we can go to each item and perform action on each indivdual item

# %%
fruits = ["apple", "grape","pears"]
for fruit in fruits:  
    print(fruit + "pies")
# Out:
# applepies
# grapepies
# pearspies
